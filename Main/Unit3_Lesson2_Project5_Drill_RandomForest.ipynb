# %%
import pandas as pd
pd.set_option('float_format', '{:.2f}'.format)
pd.set_option('display.max_columns', 999)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import ensemble
from sklearn.model_selection import cross_val_score
# %matplotlib inline
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
# Replace the path with the correct path for your data.
y2015 = pd.read_csv(
    "../Datasets/LoanStats3d.csv",
    skipinitialspace=True,
    header=1
)

# Note the warning about dtypes.
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (0,19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
y2015.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        nan   24700.00     24700.00         24700.00   36 months
# 1  NaN        nan   35000.00     35000.00         35000.00   60 months
# 2  NaN        nan    3600.00      3600.00          3600.00   36 months
# 3  NaN        nan   10400.00     10400.00         10400.00   60 months
# 4  NaN        nan   20000.00     20000.00         20000.00   60 months
#
#   int_rate  installment grade sub_grade                    emp_title  \
# 0   11.99%       820.28     C        C1                     Engineer
# 1   14.85%       829.90     C        C5  Information Systems Officer
# 2   13.99%       123.03     C        C4                      leadman
# 3   22.45%       289.91     F        F1          Contract Specialist
# 4   10.78%       432.66     B        B4                 truck driver
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0  10+ years       MORTGAGE    65000.00        Not Verified  Dec-2015
# 1  10+ years       MORTGAGE   110000.00     Source Verified  Dec-2015
# 2  10+ years       MORTGAGE    55000.00        Not Verified  Dec-2015
# 3    3 years       MORTGAGE   104433.00     Source Verified  Dec-2015
# 4  10+ years       MORTGAGE    63000.00        Not Verified  Dec-2015
#
#   loan_status pymnt_plan  url desc             purpose               title  \
# 0  Fully Paid          n  nan  NaN      small_business            Business
# 1     Current          n  nan  NaN  debt_consolidation  Debt consolidation
# 2  Fully Paid          n  nan  NaN  debt_consolidation  Debt consolidation
# 3  Fully Paid          n  nan  NaN      major_purchase      Major purchase
# 4  Fully Paid          n  nan  NaN    home_improvement                 NaN
#
#   zip_code addr_state   dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0    577xx         SD 16.06         1.00         Dec-1999            4.00
# 1    076xx         NJ 17.06         0.00         Sep-2008            0.00
# 2    190xx         PA  5.91         0.00         Aug-2003            1.00
# 3    174xx         PA 25.37         1.00         Jun-1998            3.00
# 4    605xx         IL 10.78         0.00         Aug-2000            0.00
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                    6.00                     nan     22.00     0.00
# 1                     nan                     nan     13.00     0.00
# 2                   30.00                     nan      7.00     0.00
# 3                   12.00                     nan     12.00     0.00
# 4                     nan                     nan      6.00     0.00
#
#    revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0   21470.00      19.2%      38.00                   w       0.00
# 1    7802.00      11.6%      17.00                   w   15264.49
# 2    2765.00      29.7%      13.00                   w       0.00
# 3   21929.00      64.5%      35.00                   w       0.00
# 4    7869.00      56.2%      18.00                   w       0.00
#
#    out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0           0.00     25679.66         25679.66         24700.00
# 1       15264.49     32293.91         32293.91         19735.51
# 2           0.00      4421.72          4421.72          3600.00
# 3           0.00     11740.50         11740.50         10400.00
# 4           0.00     22705.92         22705.92         20000.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         979.66                0.00        0.00                     0.00
# 1       12558.40                0.00        0.00                     0.00
# 2         821.72                0.00        0.00                     0.00
# 3        1340.50                0.00        0.00                     0.00
# 4        2705.92                0.00        0.00                     0.00
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Jun-2016           926.35          NaN           Apr-2019
# 1     Apr-2019           829.90     Apr-2019           Apr-2019
# 2     Jan-2019           122.67          NaN           Apr-2019
# 3     Jul-2016         10128.96          NaN           Mar-2018
# 4     Jun-2017         15813.30          NaN           Mar-2019
#
#    collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0       0.00        314017.00           39475.00        79300.00
# 1       0.00        381215.00           52226.00        62500.00
# 2       0.00        178050.00            7746.00         2400.00
# 3       0.00        439570.00           95768.00        20300.00
# 4       0.00        218418.00           18696.00         6200.00
#
#    total_il_high_credit_limit  revol_bal_joint  sec_app_earliest_cr_line  \
# 0                    24667.00              nan                       nan
# 1                    18000.00              nan                       nan
# 2                    13734.00              nan                       nan
# 3                    88097.00              nan                       nan
# 4                    14877.00              nan                       nan
#
#    sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                     nan               nan               nan
# 1                     nan               nan               nan
# 2                     nan               nan               nan
# 3                     nan               nan               nan
# 4                     nan               nan               nan
#
#    sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                 nan                  nan                    nan
# 1                 nan                  nan                    nan
# 2                 nan                  nan                    nan
# 3                 nan                  nan                    nan
# 4                 nan                  nan                    nan
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               nan                                 nan
# 1                               nan                                 nan
# 2                               nan                                 nan
# 3                               nan                                 nan
# 4                               nan                                 nan
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  nan             N           NaN
# 1                                  nan             N           NaN
# 2                                  nan             N           NaN
# 3                                  nan             N           NaN
# 4                                  nan             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            nan              nan
# 1             NaN             NaN            nan              nan
# 2             NaN             NaN            nan              nan
# 3             NaN             NaN            nan              nan
# 4             NaN             NaN            nan              nan
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              nan           nan                  NaN
# 1              nan           nan                  NaN
# 2              nan           nan                  NaN
# 3              nan           nan                  NaN
# 4              nan           nan                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         nan                             nan
# 1                                         nan                             nan
# 2                                         nan                             nan
# 3                                         nan                             nan
# 4                                         nan                             nan
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                           nan                    N
# 1                           nan                    N
# 2                           nan                    N
# 3                           nan                    N
# 4                           nan                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                nan                    nan              nan
# 1                nan                    nan              nan
# 2                nan                    nan              nan
# 3                nan                    nan              nan
# 4                nan                    nan              nan

# %%
# Remove two summary rows at the end that don't actually contain data.
y2015 = y2015[:-2]

# %%
# Convert ID and Interest Rate to numeric.
y2015['id'] = pd.to_numeric(y2015['id'], errors='coerce')
y2015['int_rate'] = pd.to_numeric(y2015['int_rate'].str.strip('%'), errors='coerce')

# Drop other columns with many unique variables
y2015.drop(['url', 'emp_title', 'zip_code', 'earliest_cr_line', 'revol_util',
            'sub_grade', 'addr_state', 'desc'], 1, inplace=True)

# %%
y2015.describe()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# count 0.00       0.00  421095.00    421095.00        421095.00 421095.00
# mean   nan        nan   15240.29     15240.29         15234.16     12.60
# std    nan        nan    8571.33      8571.33          8567.94      4.32
# min    nan        nan    1000.00      1000.00           900.00      5.32
# 25%    nan        nan    8500.00      8500.00          8500.00      9.17
# 50%    nan        nan   14000.00     14000.00         14000.00     12.29
# 75%    nan        nan   20000.00     20000.00         20000.00     15.59
# max    nan        nan   35000.00     35000.00         35000.00     28.99
#
#        installment  annual_inc       dti  delinq_2yrs  inq_last_6mths  \
# count    421095.00   421095.00 421093.00    421095.00       421095.00
# mean        441.84    76965.61     19.15         0.35            0.57
# std         244.85    73949.96      8.89         0.93            0.87
# min          14.01        0.00      0.00         0.00            0.00
# 25%         263.93    46000.00     12.59         0.00            0.00
# 50%         385.41    65000.00     18.60         0.00            0.00
# 75%         578.79    91690.50     25.34         0.00            1.00
# max        1445.46  9500000.00    999.00        39.00            6.00
#
#        mths_since_last_delinq  mths_since_last_record  open_acc   pub_rec  \
# count               217133.00                74415.00 421095.00 421095.00
# mean                    34.02                   66.59     11.95      0.23
# std                     21.99                   25.58      5.63      0.65
# min                      0.00                    0.00      1.00      0.00
# 25%                     15.00                   50.00      8.00      0.00
# 50%                     31.00                   67.00     11.00      0.00
# 75%                     50.00                   82.00     15.00      0.00
# max                    176.00                  120.00     90.00     86.00
#
#        revol_bal  total_acc  out_prncp  out_prncp_inv  total_pymnt  \
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# count          421095.00       421095.00                   421095.00
# mean            52221.99        21958.21                    43478.65
# std             49074.94        21840.37                    43942.71
# min                 0.00            0.00                        0.00
# 25%             22598.50         7800.00                    15481.50
# 50%             39596.00        15200.00                    32970.00
# 75%             65651.00        28600.00                    58299.00
# max           2921551.00       834300.00                  2101913.00
#
#        revol_bal_joint  sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# count             0.00                      0.00                    0.00
# mean               nan                       nan                     nan
# std                nan                       nan                     nan
# min                nan                       nan                     nan
# 25%                nan                       nan                     nan
# 50%                nan                       nan                     nan
# 75%                nan                       nan                     nan
# max                nan                       nan                     nan
#
#        sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# count              0.00              0.00                0.00
# mean                nan               nan                 nan
# std                 nan               nan                 nan
# min                 nan               nan                 nan
# 25%                 nan               nan                 nan
# 50%                 nan               nan                 nan
# 75%                 nan               nan                 nan
# max                 nan               nan                 nan
#
#        sec_app_open_act_il  sec_app_num_rev_accts  \
# count                 0.00                   0.00
# mean                   nan                    nan
# std                    nan                    nan
# min                    nan                    nan
# 25%                    nan                    nan
# 50%                    nan                    nan
# 75%                    nan                    nan
# max                    nan                    nan
#
#        sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# count                              0.00                                0.00
# mean                                nan                                 nan
# std                                 nan                                 nan
# min                                 nan                                 nan
# 25%                                 nan                                 nan
# 50%                                 nan                                 nan
# 75%                                 nan                                 nan
# max                                 nan                                 nan
#
#        sec_app_mths_since_last_major_derog  deferral_term  hardship_amount  \
# count                                 0.00        2590.00          2590.00
# mean                                   nan           3.00           118.30
# std                                    nan           0.00            96.74
# min                                    nan           3.00             0.64
# 25%                                    nan           3.00            41.45
# 50%                                    nan           3.00            93.56
# 75%                                    nan           3.00           166.97
# max                                    nan           3.00           638.13
#
#        hardship_length  hardship_dpd  \
# count          2590.00       2590.00
# mean              3.00         14.22
# std               0.00          9.69
# min               3.00          0.00
# 25%               3.00          7.00
# 50%               3.00         15.00
# 75%               3.00         23.00
# max               3.00         30.00
#
#        orig_projected_additional_accrued_interest  \
# count                                     2106.00
# mean                                       350.53
# std                                        284.79
# min                                          1.92
# 25%                                        123.46
# 50%                                        278.38
# 75%                                        497.15
# max                                       1914.39
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# count                         2590.00                       2590.00
# mean                          9278.74                        183.12
# std                           6111.48                        180.85
# min                             55.73                          0.02
# 25%                           4168.23                         42.77
# 50%                           8242.83                        131.61
# 75%                          13231.98                        272.44
# max                          29401.04                       1247.48
#
#        settlement_amount  settlement_percentage  settlement_term
# count           11695.00               11695.00         11695.00
# mean             4853.92                  47.19            12.83
# std              3505.01                   6.20             7.79
# min               107.00                  20.00             0.00
# 25%              2127.99                  45.00             6.00
# 50%              4149.00                  45.00            12.00
# 75%              6690.83                  50.00            18.00
# max             30000.00                 166.67           112.00

# %% [markdown]
# ## Reference model

# %%
from sklearn import ensemble
from sklearn.model_selection import cross_val_score

rfc = ensemble.RandomForestClassifier()
X = y2015.drop('loan_status', 1)
Y = y2015['loan_status']
X = pd.get_dummies(X)
X = X.dropna(axis=1)

score = cross_val_score(rfc, X, Y, cv=10)
print("Accuracy: %0.3f (+/- %0.3f)" % (score.mean(), score.std() * 2))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy: 0.992 (+/- 0.003)

# %% [markdown]
# ## DRILL: Third Attempt
#
# So here's your task. Get rid of as much data as possible without dropping below an average of 90% accuracy in a 10-fold cross validation.
#
# You'll want to do a few things in this process. First, dive into the data that we have and see which features are most important. This can be the raw features or the generated dummies. You may want to use PCA or correlation matrices.
#
# Can you do it without using anything related to payment amount or outstanding principal? How do you know?

# %%
col_y = y2015['loan_status']
y2015.drop(labels=['loan_status'], axis=1,inplace = True)
y2015.insert(0, 'loan_status', col_y)
df_dumm = pd.get_dummies(y2015)
df_dumm = df_dumm.dropna(axis=1)

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=10):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(df_dumm, 100).to_string())
# Out:
# Top Absolute Correlations
# loan_amnt                                      funded_amnt                              1.00
# hardship_start_date_Apr-2017                   payment_plan_start_date_Apr-2017         1.00
# hardship_flag_Y                                hardship_status_ACTIVE                   1.00
# hardship_flag_N                                hardship_status_ACTIVE                   1.00
# purpose_educational                            title_Learning and training              1.00
# hardship_end_date_Jul-2019                     payment_plan_start_date_May-2019         1.00
# hardship_flag_N                                hardship_flag_Y                          1.00
# application_type_Joint App                     verification_status_joint_Not Verified   1.00
# application_type_Individual                    verification_status_joint_Not Verified   1.00
# hardship_end_date_Jun-2019                     payment_plan_start_date_Apr-2019         1.00
# application_type_Individual                    application_type_Joint App               1.00
# debt_settlement_flag_N                         debt_settlement_flag_Y                   1.00
# hardship_end_date_Mar-2017                     payment_plan_start_date_Feb-2017         1.00
# term_ 36 months                                term_ 60 months                          1.00
# initial_list_status_f                          initial_list_status_w                    1.00
# pymnt_plan_n                                   pymnt_plan_y                             1.00
# out_prncp                                      out_prncp_inv                            1.00
# total_pymnt                                    total_pymnt_inv                          1.00
# funded_amnt                                    funded_amnt_inv                          1.00
# loan_amnt                                      funded_amnt_inv                          1.00
# open_acc                                       num_sats                                 1.00
# purpose_moving                                 title_Moving and relocation              1.00
# purpose_vacation                               title_Vacation                           1.00
# purpose_home_improvement                       title_Home improvement                   1.00
# purpose_major_purchase                         title_Major purchase                     1.00
# purpose_credit_card                            title_Credit card refinancing            1.00
# purpose_debt_consolidation                     title_Debt consolidation                 1.00
# purpose_medical                                title_Medical expenses                   1.00
# purpose_house                                  title_Home buying                        1.00
# purpose_other                                  title_Other                              1.00
# purpose_small_business                         title_Business                           1.00
# purpose_car                                    title_Car financing                      1.00
# purpose_renewable_energy                       title_Green loan                         0.99
# recoveries                                     collection_recovery_fee                  0.99
# num_actv_rev_tl                                num_rev_tl_bal_gt_0                      0.98
# tot_cur_bal                                    tot_hi_cred_lim                          0.97
# total_pymnt_inv                                total_rec_prncp                          0.96
# total_pymnt                                    total_rec_prncp                          0.96
# funded_amnt                                    installment                              0.94
# loan_amnt                                      installment                              0.94
# funded_amnt_inv                                installment                              0.94
# hardship_end_date_May-2019                     payment_plan_start_date_Mar-2019         0.91
# last_pymnt_d_Apr-2019                          next_pymnt_d_May-2019                    0.90
# hardship_type_INTEREST ONLY-3 MONTHS DEFERRAL  hardship_status_COMPLETED                0.89
# funded_amnt_inv                                total_pymnt_inv                          0.88
#                                                total_pymnt                              0.88
# loan_amnt                                      total_pymnt                              0.88
# funded_amnt                                    total_pymnt                              0.88
#                                                total_pymnt_inv                          0.88
# loan_amnt                                      total_pymnt_inv                          0.88
# out_prncp_inv                                  loan_status_Current                      0.87
# out_prncp                                      loan_status_Current                      0.87
# total_bal_ex_mort                              total_il_high_credit_limit               0.86
# installment                                    total_pymnt                              0.84
#                                                total_pymnt_inv                          0.84
# num_actv_bc_tl                                 num_bc_sats                              0.84
# pymnt_plan_y                                   hardship_status_ACTIVE                   0.84
# pymnt_plan_n                                   hardship_flag_N                          0.84
# pymnt_plan_y                                   hardship_flag_Y                          0.84
#                                                hardship_flag_N                          0.84
# pymnt_plan_n                                   hardship_status_ACTIVE                   0.84
#                                                hardship_flag_Y                          0.84
# tot_cur_bal                                    avg_cur_bal                              0.83
# revol_bal                                      total_rev_hi_lim                         0.83
# open_acc                                       num_op_rev_tl                            0.83
# num_op_rev_tl                                  num_sats                                 0.83
# last_pymnt_d_Mar-2019                          next_pymnt_d_Apr-2019                    0.82
# hardship_start_date_Feb-2017                   payment_plan_start_date_Feb-2017         0.82
#                                                hardship_end_date_Mar-2017               0.82
# hardship_start_date_Mar-2017                   payment_plan_start_date_Mar-2017         0.82
# hardship_end_date_Apr-2019                     payment_plan_start_date_Feb-2019         0.82
# num_op_rev_tl                                  num_rev_tl_bal_gt_0                      0.81
# num_actv_rev_tl                                num_op_rev_tl                            0.81
# num_actv_bc_tl                                 num_actv_rev_tl                          0.81
# home_ownership_MORTGAGE                        home_ownership_RENT                      0.80
# num_actv_bc_tl                                 num_rev_tl_bal_gt_0                      0.80
# funded_amnt_inv                                total_rec_prncp                          0.80
# funded_amnt                                    total_rec_prncp                          0.80
# loan_amnt                                      total_rec_prncp                          0.80
# avg_cur_bal                                    tot_hi_cred_lim                          0.80
# installment                                    total_rec_prncp                          0.79
# acc_now_delinq                                 num_tl_30dpd                             0.79
# pymnt_plan_n                                   hardship_start_date_Mar-2019             0.79
# pymnt_plan_y                                   hardship_start_date_Mar-2019             0.79
# hardship_start_date_May-2018                   payment_plan_start_date_May-2018         0.77
# loan_status_Current                            last_pymnt_d_Apr-2019                    0.77
# hardship_start_date_May-2017                   payment_plan_start_date_May-2017         0.76
# acc_open_past_24mths                           num_tl_op_past_12m                       0.76
# hardship_end_date_Apr-2018                     payment_plan_start_date_Feb-2018         0.75
# hardship_end_date_Nov-2017                     payment_plan_start_date_Sep-2017         0.75
# hardship_end_date_Dec-2017                     payment_plan_start_date_Oct-2017         0.75
# hardship_end_date_Jan-2019                     payment_plan_start_date_Nov-2018         0.74
# loan_status_Charged Off                        loan_status_Fully Paid                   0.74
# num_bc_sats                                    num_op_rev_tl                            0.74
#                                                num_bc_tl                                0.73
# hardship_start_date_Sep-2017                   payment_plan_start_date_Sep-2017         0.73
# debt_settlement_flag_N                         settlement_status_COMPLETE               0.73
# debt_settlement_flag_Y                         settlement_status_COMPLETE               0.73
# hardship_reason_NATURAL_DISASTER               hardship_start_date_Sep-2017             0.72
# pub_rec                                        tax_liens                                0.72

# %%
# Your code here.

rfc = ensemble.RandomForestClassifier()
X = y2015.drop([ 
               "loan_status", # is Y 
               "id",
               "member_id",
               "loan_amnt",
               "funded_amnt",
               "funded_amnt_inv",
               "term",
               "int_rate",
               "installment",
               "grade",
               "emp_length",
               "home_ownership",
               "annual_inc",
               "verification_status",
               "issue_d",
               "pymnt_plan",
               "purpose",
               "title",
               "dti",
               "delinq_2yrs",
               "inq_last_6mths",
               "mths_since_last_delinq",
               "mths_since_last_record",
               "open_acc",
               "pub_rec",
               "revol_bal",
               "total_acc",
               "initial_list_status",
               #"out_prncp",
               #"out_prncp_inv",
               "total_pymnt",
               "total_pymnt_inv",
               "total_rec_prncp",
               "total_rec_int",
               "total_rec_late_fee",
               #"recoveries",
               "collection_recovery_fee",
               "last_pymnt_d",
               "last_pymnt_amnt",
               "next_pymnt_d",
               "last_credit_pull_d",
               "collections_12_mths_ex_med",
               "mths_since_last_major_derog",
               "policy_code",
               "application_type",
               "annual_inc_joint",
               "dti_joint",
               "verification_status_joint",
               "acc_now_delinq",
               "tot_coll_amt",
               "tot_cur_bal",
               "open_acc_6m",
               "open_act_il",
               "open_il_12m",
               "open_il_24m",
               "mths_since_rcnt_il",
               "total_bal_il",
               "il_util",
               "open_rv_12m",
               "open_rv_24m",
               "max_bal_bc",
               "all_util",
               "total_rev_hi_lim",
               "inq_fi",
               "total_cu_tl",
               "inq_last_12m",
               "acc_open_past_24mths",
               "avg_cur_bal","bc_open_to_buy",
               "bc_util",
               "chargeoff_within_12_mths",
               "delinq_amnt",
               "mo_sin_old_il_acct",
               "mo_sin_old_rev_tl_op",
               "mo_sin_rcnt_rev_tl_op",
               "mo_sin_rcnt_tl",
               "mort_acc",
               "mths_since_recent_bc",
               "mths_since_recent_bc_dlq",
               "mths_since_recent_inq",
               "mths_since_recent_revol_delinq",
               "num_accts_ever_120_pd",
               "num_actv_bc_tl","num_actv_rev_tl",
               "num_bc_sats",
               "num_bc_tl","num_il_tl",
               "num_op_rev_tl",
               "num_rev_accts",
               "num_rev_tl_bal_gt_0",
               "num_sats",
               "num_tl_120dpd_2m",
               "num_tl_30dpd",
               "num_tl_90g_dpd_24m",
               "num_tl_op_past_12m",
               "pct_tl_nvr_dlq",
               "percent_bc_gt_75","pub_rec_bankruptcies",
               "tax_liens","tot_hi_cred_lim",
               "total_bal_ex_mort",
               "total_bc_limit",
               "total_il_high_credit_limit",
               "revol_bal_joint",
               "sec_app_earliest_cr_line",
               "sec_app_inq_last_6mths",
               "sec_app_mort_acc","sec_app_open_acc",
               "sec_app_revol_util","sec_app_open_act_il",
               "sec_app_num_rev_accts",
               "sec_app_chargeoff_within_12_mths",
               "sec_app_collections_12_mths_ex_med",
               "sec_app_mths_since_last_major_derog",
               "hardship_flag",
               "hardship_type",
               "hardship_reason",
               "hardship_status",
               "deferral_term",
               "hardship_amount",
               "hardship_start_date",
               "hardship_end_date",
               "payment_plan_start_date",
               "hardship_length",
               "hardship_dpd",
               "hardship_loan_status",
               "orig_projected_additional_accrued_interest",
               "hardship_payoff_balance_amount",
               "hardship_last_payment_amount",
               "debt_settlement_flag",
               "debt_settlement_flag_date",
               "settlement_status",
               "settlement_date",
               "settlement_amount",
               "settlement_percentage",
               "settlement_term" ], 1)
Y = y2015['loan_status']
X = pd.get_dummies(X)
X = X.dropna(axis=1)

score = cross_val_score(rfc, X, Y, cv=10)
print("Accuracy: %0.3f (+/- %0.3f)" % (score.mean(), score.std() * 2))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy: 0.941 (+/- 0.007)

# %% [markdown]
# ### Drill achieved : Accuracy: 0.940 (+/- 0.007)
